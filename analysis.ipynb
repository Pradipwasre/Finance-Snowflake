# %% [markdown]
# # Snowflake to Python - Quick Check
#
# Connects to Snowflake, fetches `FINANCE_PROJECTS_ML_DATA`, and runs a quick `df.head(10)` check.
#
# Snowflake objects already created:
# - WAREHOUSE: `FINANCE_ML_WH`
# - DATABASE: `FINANCE_ML_DB`
# - SCHEMA: `FINANCE_PROJECTS`

# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd
import snowflake.connector
import getpass


password = getpass.getpass("Enter your Snowflake password: ")

conn = snowflake.connector.connect(
    account="EJVGHYR-CH39687",
    user="PRADIPBUILDS",
    password=password,
    role="ACCOUNTADMIN",
    warehouse="FINANCE_ML_WH",
    database="FINANCE_ML_DB",
    schema="FINANCE_PROJECTS"
)

print("Connected to Snowflake successfully.")
# Out:
# Connected to Snowflake successfully.

# %%
query = """
    SELECT *
    FROM FINANCE_ML_DB.FINANCE_PROJECTS.FINANCE_PROJECTS_ML_DATA
"""

df = pd.read_sql(query, conn)

print(f"Shape: {df.shape}")
# Out:
# /var/folders/0n/3ybt7fdd76d2fs4ghfx5f5f00000gn/T/ipykernel_11599/953332882.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Shape: (10000, 28)

# %% [markdown]
# ## Quick check: df.head(10)

# %%
df.head(10)
# Out:
#    PROJECT_ID PROJECT_START_DATE     FINANCE_DOMAIN            PROJECT_TYPE  \
# 0           1         2021-02-07          INSURANCE         FRAUD_DETECTION
# 1           2         2021-03-16           PAYMENTS          RISK_ANALYTICS
# 2           3         2021-04-22  WEALTH_MANAGEMENT      CUSTOMER_ANALYTICS
# 3           4         2021-05-29            LENDING    REGULATORY_REPORTING
# 4           5         2021-07-05    CAPITAL_MARKETS       COST_OPTIMIZATION
# 5           6         2021-08-11            BANKING         CLOUD_MIGRATION
# 6           7         2021-09-17          INSURANCE           DATA_PLATFORM
# 7           8         2021-10-24           PAYMENTS  DIGITAL_TRANSFORMATION
# 8           9         2021-11-30  WEALTH_MANAGEMENT         FRAUD_DETECTION
# 9          10         2022-01-06            LENDING          RISK_ANALYTICS
#
#   PROJECT_PRIORITY PROJECT_STATUS DELIVERY_MODEL  TEAM_SIZE  \
# 0           MEDIUM      COMPLETED         VENDOR         23
# 1              LOW      COMPLETED         HYBRID         36
# 2             HIGH      COMPLETED       IN_HOUSE         49
# 3           MEDIUM      COMPLETED         VENDOR         62
# 4              LOW      COMPLETED         HYBRID         75
# 5             HIGH      COMPLETED       IN_HOUSE         88
# 6           MEDIUM      COMPLETED         VENDOR         10
# 7              LOW      COMPLETED         HYBRID         23
# 8             HIGH      COMPLETED       IN_HOUSE         36
# 9           MEDIUM      COMPLETED         VENDOR         49
#
#    PROJECT_DURATION_MONTHS  PLANNED_BUDGET  ...  DELAYED_MILESTONES  \
# 0                       10        157919.0  ...                   8
# 1                       17        165838.0  ...                   3
# 2                       24        173757.0  ...                  11
# 3                       31        181676.0  ...                   6
# 4                        4        189595.0  ...                   1
# 5                       11        197514.0  ...                   9
# 6                       18        205433.0  ...                   4
# 7                       25        213352.0  ...                  12
# 8                       32        221271.0  ...                   7
# 9                        5        229190.0  ...                   2
#
#    OPEN_DEFECTS  RESOURCE_UTILIZATION_RATIO  INFLATION_RATE  INTEREST_RATE  \
# 0             6                        0.68           0.081          0.041
# 1            10                        0.81           0.061          0.047
# 2            14                        0.94           0.041          0.053
# 3            18                        0.61           0.021          0.059
# 4            22                        0.74           0.082          0.065
# 5            26                        0.87           0.062          0.071
# 6            30                        1.00           0.042          0.077
# 7            34                        0.67           0.022          0.083
# 8            38                        0.80           0.083          0.089
# 9            42                        0.93           0.063          0.095
#
#    FX_VOLATILITY  PREVIOUS_PROJECT_COST  PREVIOUS_PROJECT_DELAY_DAYS  \
# 0          0.081               100073.0                           79
# 1          0.061               100146.0                           37
# 2          0.041               100219.0                          116
# 3          0.021               100292.0                           74
# 4          0.092               100365.0                           32
# 5          0.072               100438.0                          111
# 6          0.052               100511.0                           69
# 7          0.032               100584.0                           27
# 8          0.012               100657.0                          106
# 9          0.083               100730.0                           64
#
#    TEAM_PRODUCTIVITY_SCORE  ACTUAL_PROJECT_COST
# 0                     92.0            598821.16
# 1                     83.0           1081579.83
# 2                     74.0           1608093.06
# 3                     65.0           1841505.61
# 4                     56.0           1484695.24
# 5                     93.0           1988423.59
# 6                     84.0           1044977.11
# 7                     75.0           1639599.72
# 8                     66.0           1918643.24
# 9                     57.0           1618411.12
#
# [10 rows x 28 columns]

# %%
conn.close()
print("Connection closed.")
# Out:
# Connection closed.
